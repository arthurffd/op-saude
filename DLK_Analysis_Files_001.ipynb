# %%
# Installing the Azure Data Lake Store Python SDK
# !pip install azure-mgmt-resource
# !pip install azure-mgmt-datalake-store
# !pip install azure-datalake-store
# Out:
# Requirement already satisfied: azure-mgmt-resource in c:\programdata\anaconda3\lib\site-packages (4.0.0)
# Requirement already satisfied: msrestazure<2.0.0,>=0.4.32 in c:\programdata\anaconda3\lib\site-packages (from azure-mgmt-resource) (0.6.2)
# Requirement already satisfied: azure-common~=1.1 in c:\programdata\anaconda3\lib\site-packages (from azure-mgmt-resource) (1.1.23)
# Requirement already satisfied: msrest>=0.5.0 in c:\programdata\anaconda3\lib\site-packages (from azure-mgmt-resource) (0.6.10)
# Requirement already satisfied: adal<2.0.0,>=0.6.0 in c:\programdata\anaconda3\lib\site-packages (from msrestazure<2.0.0,>=0.4.32->azure-mgmt-resource) (1.2.2)
# Requirement already satisfied: isodate>=0.6.0 in c:\programdata\anaconda3\lib\site-packages (from msrest>=0.5.0->azure-mgmt-resource) (0.6.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from msrest>=0.5.0->azure-mgmt-resource) (2019.6.16)
# Requirement already satisfied: requests~=2.16 in c:\programdata\anaconda3\lib\site-packages (from msrest>=0.5.0->azure-mgmt-resource) (2.22.0)
# Requirement already satisfied: requests-oauthlib>=0.5.0 in c:\programdata\anaconda3\lib\site-packages (from msrest>=0.5.0->azure-mgmt-resource) (1.2.0)
# Requirement already satisfied: cryptography>=1.1.0 in c:\programdata\anaconda3\lib\site-packages (from adal<2.0.0,>=0.6.0->msrestazure<2.0.0,>=0.4.32->azure-mgmt-resource) (2.7)
# Requirement already satisfied: python-dateutil>=2.1.0 in c:\programdata\anaconda3\lib\site-packages (from adal<2.0.0,>=0.6.0->msrestazure<2.0.0,>=0.4.32->azure-mgmt-resource) (2.7.3)
# Requirement already satisfied: PyJWT>=1.0.0 in c:\programdata\anaconda3\lib\site-packages (from adal<2.0.0,>=0.6.0->msrestazure<2.0.0,>=0.4.32->azure-mgmt-resource) (1.7.1)
# Requirement already satisfied: six in c:\programdata\anaconda3\lib\site-packages (from isodate>=0.6.0->msrest>=0.5.0->azure-mgmt-resource) (1.11.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests~=2.16->msrest>=0.5.0->azure-mgmt-resource) (1.23)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests~=2.16->msrest>=0.5.0->azure-mgmt-resource) (2.7)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\programdata\anaconda3\lib\site-packages (from requests~=2.16->msrest>=0.5.0->azure-mgmt-resource) (3.0.4)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\programdata\anaconda3\lib\site-packages (from requests-oauthlib>=0.5.0->msrest>=0.5.0->azure-mgmt-resource) (3.1.0)
# Requirement already satisfied: asn1crypto>=0.21.0 in c:\programdata\anaconda3\lib\site-packages (from cryptography>=1.1.0->adal<2.0.0,>=0.6.0->msrestazure<2.0.0,>=0.4.32->azure-mgmt-resource) (0.24.0)
# Requirement already satisfied: cffi!=1.11.3,>=1.8 in c:\programdata\anaconda3\lib\site-packages (from cryptography>=1.1.0->adal<2.0.0,>=0.6.0->msrestazure<2.0.0,>=0.4.32->azure-mgmt-resource) (1.11.5)
# Requirement already satisfied: pycparser in c:\programdata\anaconda3\lib\site-packages (from cffi!=1.11.3,>=1.8->cryptography>=1.1.0->adal<2.0.0,>=0.6.0->msrestazure<2.0.0,>=0.4.32->azure-mgmt-resource) (2.18)
# Requirement already satisfied: azure-mgmt-datalake-store in c:\programdata\anaconda3\lib\site-packages (0.5.0)
# Requirement already satisfied: azure-common~=1.1 in c:\programdata\anaconda3\lib\site-packages (from azure-mgmt-datalake-store) (1.1.23)
# Requirement already satisfied: msrestazure<2.0.0,>=0.4.27 in c:\programdata\anaconda3\lib\site-packages (from azure-mgmt-datalake-store) (0.6.2)
# Requirement already satisfied: azure-mgmt-datalake-nspkg>=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from azure-mgmt-datalake-store) (3.0.1)
# Requirement already satisfied: msrest<2.0.0,>=0.6.0 in c:\programdata\anaconda3\lib\site-packages (from msrestazure<2.0.0,>=0.4.27->azure-mgmt-datalake-store) (0.6.10)
# Requirement already satisfied: adal<2.0.0,>=0.6.0 in c:\programdata\anaconda3\lib\site-packages (from msrestazure<2.0.0,>=0.4.27->azure-mgmt-datalake-store) (1.2.2)
# Requirement already satisfied: azure-mgmt-nspkg>=3.0.0 in c:\programdata\anaconda3\lib\site-packages (from azure-mgmt-datalake-nspkg>=2.0.0->azure-mgmt-datalake-store) (3.0.2)
# Requirement already satisfied: requests-oauthlib>=0.5.0 in c:\programdata\anaconda3\lib\site-packages (from msrest<2.0.0,>=0.6.0->msrestazure<2.0.0,>=0.4.27->azure-mgmt-datalake-store) (1.2.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from msrest<2.0.0,>=0.6.0->msrestazure<2.0.0,>=0.4.27->azure-mgmt-datalake-store) (2019.6.16)
# Requirement already satisfied: requests~=2.16 in c:\programdata\anaconda3\lib\site-packages (from msrest<2.0.0,>=0.6.0->msrestazure<2.0.0,>=0.4.27->azure-mgmt-datalake-store) (2.22.0)
# Requirement already satisfied: isodate>=0.6.0 in c:\programdata\anaconda3\lib\site-packages (from msrest<2.0.0,>=0.6.0->msrestazure<2.0.0,>=0.4.27->azure-mgmt-datalake-store) (0.6.0)
# Requirement already satisfied: python-dateutil>=2.1.0 in c:\programdata\anaconda3\lib\site-packages (from adal<2.0.0,>=0.6.0->msrestazure<2.0.0,>=0.4.27->azure-mgmt-datalake-store) (2.7.3)
# Requirement already satisfied: PyJWT>=1.0.0 in c:\programdata\anaconda3\lib\site-packages (from adal<2.0.0,>=0.6.0->msrestazure<2.0.0,>=0.4.27->azure-mgmt-datalake-store) (1.7.1)
# Requirement already satisfied: cryptography>=1.1.0 in c:\programdata\anaconda3\lib\site-packages (from adal<2.0.0,>=0.6.0->msrestazure<2.0.0,>=0.4.27->azure-mgmt-datalake-store) (2.7)
# Requirement already satisfied: azure-nspkg>=3.0.0 in c:\programdata\anaconda3\lib\site-packages (from azure-mgmt-nspkg>=3.0.0->azure-mgmt-datalake-nspkg>=2.0.0->azure-mgmt-datalake-store) (3.0.2)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\programdata\anaconda3\lib\site-packages (from requests-oauthlib>=0.5.0->msrest<2.0.0,>=0.6.0->msrestazure<2.0.0,>=0.4.27->azure-mgmt-datalake-store) (3.1.0)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\programdata\anaconda3\lib\site-packages (from requests~=2.16->msrest<2.0.0,>=0.6.0->msrestazure<2.0.0,>=0.4.27->azure-mgmt-datalake-store) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests~=2.16->msrest<2.0.0,>=0.6.0->msrestazure<2.0.0,>=0.4.27->azure-mgmt-datalake-store) (1.23)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests~=2.16->msrest<2.0.0,>=0.6.0->msrestazure<2.0.0,>=0.4.27->azure-mgmt-datalake-store) (2.7)
# Requirement already satisfied: six in c:\programdata\anaconda3\lib\site-packages (from isodate>=0.6.0->msrest<2.0.0,>=0.6.0->msrestazure<2.0.0,>=0.4.27->azure-mgmt-datalake-store) (1.11.0)
# Requirement already satisfied: cffi!=1.11.3,>=1.8 in c:\programdata\anaconda3\lib\site-packages (from cryptography>=1.1.0->adal<2.0.0,>=0.6.0->msrestazure<2.0.0,>=0.4.27->azure-mgmt-datalake-store) (1.11.5)
# Requirement already satisfied: asn1crypto>=0.21.0 in c:\programdata\anaconda3\lib\site-packages (from cryptography>=1.1.0->adal<2.0.0,>=0.6.0->msrestazure<2.0.0,>=0.4.27->azure-mgmt-datalake-store) (0.24.0)
# Requirement already satisfied: pycparser in c:\programdata\anaconda3\lib\site-packages (from cffi!=1.11.3,>=1.8->cryptography>=1.1.0->adal<2.0.0,>=0.6.0->msrestazure<2.0.0,>=0.4.27->azure-mgmt-datalake-store) (2.18)
# Requirement already satisfied: azure-datalake-store in c:\programdata\anaconda3\lib\site-packages (0.0.47)
# Requirement already satisfied: cffi in c:\programdata\anaconda3\lib\site-packages (from azure-datalake-store) (1.11.5)
# Requirement already satisfied: adal>=0.4.2 in c:\programdata\anaconda3\lib\site-packages (from azure-datalake-store) (1.2.2)
# Requirement already satisfied: requests>=2.20.0 in c:\programdata\anaconda3\lib\site-packages (from azure-datalake-store) (2.22.0)
# Requirement already satisfied: pycparser in c:\programdata\anaconda3\lib\site-packages (from cffi->azure-datalake-store) (2.18)
# Requirement already satisfied: python-dateutil>=2.1.0 in c:\programdata\anaconda3\lib\site-packages (from adal>=0.4.2->azure-datalake-store) (2.7.3)
# Requirement already satisfied: PyJWT>=1.0.0 in c:\programdata\anaconda3\lib\site-packages (from adal>=0.4.2->azure-datalake-store) (1.7.1)
# Requirement already satisfied: cryptography>=1.1.0 in c:\programdata\anaconda3\lib\site-packages (from adal>=0.4.2->azure-datalake-store) (2.7)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.20.0->azure-datalake-store) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.20.0->azure-datalake-store) (2019.6.16)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.20.0->azure-datalake-store) (1.23)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.20.0->azure-datalake-store) (2.7)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil>=2.1.0->adal>=0.4.2->azure-datalake-store) (1.11.0)
# Requirement already satisfied: asn1crypto>=0.21.0 in c:\programdata\anaconda3\lib\site-packages (from cryptography>=1.1.0->adal>=0.4.2->azure-datalake-store) (0.24.0)

# %%
# import libs
import pandas as pd
import numpy as np
from azure.datalake.store import core, lib, multithread, logging

# %%
# Create an ADLS File System Client. Connect using credentials and data lake store name.
token = lib.auth(tenant_id = '893644dc-5968-475b-a33a-8f27ba9efee0',
                 client_secret = '_-Ydv=:JDuf7F4NS2gZDmhqE6+jjI1+q',
                 client_id = '35db8ed1-865e-4e1e-8a15-e48695ef787e')
adl = core.AzureDLFileSystem(token, store_name='arthurffd001dlk')

# %%
# logging.basicConfig(level='warning')

# %%
# opening custos csv from datalake, reading chunks with 1000 rows
with adl.open('dimCustos/dlk_custos.csv', 'rb') as f:
    df = pd.read_csv(f, chunksize=1000)
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     170             conn = connection.create_connection(
# --> 171                 (self._dns_host, self.port), self.timeout, **extra_kw)
#     172
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      55
# ---> 56     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      57         af, socktype, proto, canonname, sa = res
#
# C:\ProgramData\Anaconda3\lib\socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     747     addrlist = []
# --> 748     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     749         af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 11001] getaddrinfo failed
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     342         try:
# --> 343             self._validate_conn(conn)
#     344         except (SocketTimeout, BaseSSLError) as e:
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#     848         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 849             conn.connect()
#     850
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connection.py in connect(self)
#     313         # Add certificate verification
# --> 314         conn = self._new_conn()
#     315
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     179             raise NewConnectionError(
# --> 180                 self, "Failed to establish a new connection: %s" % e)
#     181
#
# NewConnectionError: <urllib3.connection.VerifiedHTTPSConnection object at 0x00000238A3825C88>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     637             retries = retries.increment(method, url, error=e, _pool=self,
# --> 638                                         _stacktrace=sys.exc_info()[2])
#     639             retries.sleep()
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     397         if new_retry.is_exhausted():
# --> 398             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     399
#
# MaxRetryError: HTTPSConnectionPool(host='login.microsoftonline.com', port=443): Max retries exceeded with url: /893644dc-5968-475b-a33a-8f27ba9efee0/oauth2/token (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x00000238A3825C88>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-93-92927288493d> in <module>()
#       1 # opening custos csv from datalake, reading chunks with 1000 rows
# ----> 2 with adl.open('dimCustos/dlk_custos.csv', 'rb') as f:
#       3     df = pd.read_csv(f, chunksize=1000)
#
# C:\ProgramData\Anaconda3\lib\site-packages\azure\datalake\store\core.py in open(self, path, mode, blocksize, delimiter)
#     113                                       " and manage bytes" % (mode[0] + 'b'))
#     114         return AzureDLFile(self, AzureDLPath(path), mode, blocksize=blocksize,
# --> 115                            delimiter=delimiter)
#     116
#     117     def _ls_batched(self, path, batch_size=4000):
#
# C:\ProgramData\Anaconda3\lib\site-packages\azure\datalake\store\core.py in __init__(self, azure, path, mode, blocksize, delimiter)
#     994         # that may be created or written to (for the first time).
#     995         try:
# --> 996             file_data = self.azure.info(path, invalidate_cache=True, expected_error_code=404)
#     997             exists = True
#     998         except FileNotFoundError:
#
# C:\ProgramData\Anaconda3\lib\site-packages\azure\datalake\store\core.py in info(self, path, invalidate_cache, expected_error_code)
#     205         # simply return the result of a GETFILESTATUS from the service
#     206         if invalidate_cache or path_as_posix in {'/', '.'}:
# --> 207             to_return = self.azure.call('GETFILESTATUS', path_as_posix, expected_error_code=expected_error_code)[
#     208                 'FileStatus']
#     209             to_return['name'] = path_as_posix
#
# C:\ProgramData\Anaconda3\lib\site-packages\azure\datalake\store\lib.py in call(self, op, path, is_extended, expected_error_code, retry_policy, headers, **kwargs)
#     407             retry_count += 1
#     408             last_exception = None
# --> 409             self._check_token()
#     410             try:
#     411                 response = self.__call_once(method=method,
#
# C:\ProgramData\Anaconda3\lib\site-packages\azure\datalake\store\lib.py in _check_token(self, retry_policy)
#     305                 self.head = {'Authorization': cur_session.headers['Authorization']}
#     306                 self.local.session = None
# --> 307         check_token_internal()
#     308
#     309     def _log_request(self, method, url, op, path, params, headers, retry_count):
#
# C:\ProgramData\Anaconda3\lib\site-packages\azure\datalake\store\retry.py in f_retry(*args, **kwargs)
#      91                 retry_count += 1
#      92                 try:
# ---> 93                     out = func(*args, **kwargs)
#      94                 except (adal.adal_error.AdalError, HTTPError) as e:
#      95                     # ADAL error corresponds to everything but 429, which bubbles up HTTP error.
#
# C:\ProgramData\Anaconda3\lib\site-packages\azure\datalake\store\lib.py in check_token_internal()
#     301         @retry_decorator_for_auth(retry_policy=retry_policy)
#     302         def check_token_internal():
# --> 303             cur_session = self.token.signed_session()
#     304             if not self.head or self.head.get('Authorization') != cur_session.headers['Authorization']:
#     305                 self.head = {'Authorization': cur_session.headers['Authorization']}
#
# C:\ProgramData\Anaconda3\lib\site-packages\azure\datalake\store\lib.py in signed_session(self)
#     170         session = requests.Session()
#     171         if time.time() - self.token['time'] > self.token['expiresIn'] - 100:
# --> 172             self.refresh_token()
#     173
#     174         scheme, token = self.token['tokenType'], self.token['access']
#
# C:\ProgramData\Anaconda3\lib\site-packages\azure\datalake\store\lib.py in refresh_token(self, authority)
#     197             out = context.acquire_token_with_client_credentials(self.token['resource'],
#     198                                                                 self.token['client'],
# --> 199                                                                 self.token['secret'])
#     200             out.update({'secret': self.token['secret']})
#     201         else:
#
# C:\ProgramData\Anaconda3\lib\site-packages\adal\authentication_context.py in acquire_token_with_client_credentials(self, resource, client_id, client_secret)
#     177             return token_request.get_token_with_client_credentials(client_secret)
#     178
# --> 179         return self._acquire_token(token_func)
#     180
#     181     def acquire_token_with_authorization_code(self, authorization_code,
#
# C:\ProgramData\Anaconda3\lib\site-packages\adal\authentication_context.py in _acquire_token(self, token_func, correlation_id)
#     126             correlation_id or self.correlation_id, self._call_context.get('enable_pii', False))
#     127         self.authority.validate(self._call_context)
# --> 128         return token_func(self)
#     129
#     130     def acquire_token(self, resource, user_id, client_id):
#
# C:\ProgramData\Anaconda3\lib\site-packages\adal\authentication_context.py in token_func(self)
#     175         def token_func(self):
#     176             token_request = TokenRequest(self._call_context, self, client_id, resource)
# --> 177             return token_request.get_token_with_client_credentials(client_secret)
#     178
#     179         return self._acquire_token(token_func)
#
# C:\ProgramData\Anaconda3\lib\site-packages\adal\token_request.py in get_token_with_client_credentials(self, client_secret)
#     308         oauth_parameters[OAUTH2_PARAMETERS.CLIENT_SECRET] = client_secret
#     309
# --> 310         token = self._oauth_get_token(oauth_parameters)
#     311         self._cache_driver.add(token)
#     312         return token
#
# C:\ProgramData\Anaconda3\lib\site-packages\adal\token_request.py in _oauth_get_token(self, oauth_parameters)
#     110     def _oauth_get_token(self, oauth_parameters):
#     111         client = self._create_oauth2_client()
# --> 112         return client.get_token(oauth_parameters)
#     113
#     114     def _create_cache_driver(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\adal\oauth2_client.py in get_token(self, oauth_parameters)
#     266                                  verify=self._call_context.get('verify_ssl', None),
#     267                                  proxies=self._call_context.get('proxies', None),
# --> 268                                  timeout=self._call_context.get('timeout', None))
#     269
#     270             util.log_return_correlation_id(self._log, operation, resp)
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\api.py in post(url, data, json, **kwargs)
#     114     """
#     115
# --> 116     return request('post', url, data=data, json=json, **kwargs)
#     117
#     118
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     514                 raise SSLError(e, request=request)
#     515
# --> 516             raise ConnectionError(e, request=request)
#     517
#     518         except ClosedPoolError as e:
#
# ConnectionError: HTTPSConnectionPool(host='login.microsoftonline.com', port=443): Max retries exceeded with url: /893644dc-5968-475b-a33a-8f27ba9efee0/oauth2/token (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x00000238A3825C88>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))

# %%
#get chunk #1
df2 = df.get_chunk(50)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-92-a7eee84be1ad> in <module>()
#       1 #get chunk #1
# ----> 2 df2 = df.get_chunk(50)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in get_chunk(self, size)
#    1068                 raise StopIteration
#    1069             size = min(size, self.nrows - self._currow)
# -> 1070         return self.read(nrows=size)
#    1071
#    1072
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in read(self, nrows)
#    1034                 raise ValueError('skipfooter not supported for iteration')
#    1035
# -> 1036         ret = self._engine.read(nrows)
#    1037
#    1038         # May alter columns / col_dict
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in read(self, nrows)
#    1846     def read(self, nrows=None):
#    1847         try:
# -> 1848             data = self._reader.read(nrows)
#    1849         except StopIteration:
#    1850             if self._first_chunk:
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.read()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._read_low_memory()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._tokenize_rows()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.raise_parser_error()
#
# ValueError: I/O operation on closed file.

# %%
df2.head(100)
# Out:
#        CODIGO_BENEFICIARIO  COMPETENCIA  NUM_GUIA  NUM_GUIA_PRINCIPAL  \
# 784  0025.5974.002703.10-4       201901     50696               50696
# 785  0025.5974.002703.10-4       201901     50696               50696
#
#     DATA_EXECUCAO CID_COD DATA_INICIO_INTERNACAO DATA_FIM_INTERNACAO  \
# 784    26/09/2018     Z00             24/09/2018          18/10/2018
# 785    26/09/2018     Z00             24/09/2018          18/10/2018
#
#      COD_SOLICITANTE  COD_PREST_EXECUTANTE             ...               \
# 784               -3                    -3             ...
# 785               -3                    -3             ...
#
#      VAL_BASE_FILME  VALOR_FATURADO  IND_INTERNACAO  PARTICIPA_PREST  \
# 784               0           28,64               S              NaN
# 785               0           11,16               S              NaN
#
#     TIPO_LCTO  TIPO_ATENDIMENTO             TIPO_GUIA TIPO_INTERNACAO  \
# 784  PRODU��O               NaN  RESUMO DE INTERNA��O       CIR�RGICA
# 785  PRODU��O               NaN  RESUMO DE INTERNA��O       CIR�RGICA
#
#     TIPO_ACOMODACAO            INDICACAO_CLINICA
# 784       PRIVATIVO  conforme pedido medico,C211
# 785       PRIVATIVO  conforme pedido medico,C211
#
# [2 rows x 34 columns]

# %%
#get maximum lenght for columns
measurer = np.vectorize(len)
res1 = measurer(df2.values.astype(str)).max(axis=0)
res1
# Out:
# array([21,  6,  5,  5, 10,  3, 10, 10,  2,  2,  2,  2,  2,  8, 17,  1,  1,
#         4,  4,  1,  1,  4,  4,  1,  1,  4,  1,  3,  8,  3, 20,  9,  9, 27])

# %%
df2.shape
# Out:
# (18, 34)

# %%
# análise descritiva
df2.describe()
# Out:
#        COMPETENCIA  NUM_GUIA  NUM_GUIA_PRINCIPAL  COD_SOLICITANTE  \
# count         18.0      18.0                18.0             18.0
# mean      201901.0   50696.0             50696.0             -3.0
# std            0.0       0.0                 0.0              0.0
# min       201901.0   50696.0             50696.0             -3.0
# 25%       201901.0   50696.0             50696.0             -3.0
# 50%       201901.0   50696.0             50696.0             -3.0
# 75%       201901.0   50696.0             50696.0             -3.0
# max       201901.0   50696.0             50696.0             -3.0
#
#        COD_PREST_EXECUTANTE  COD_LOCAL_ATENDIMENTO  COD_CAPA_UNICO  \
# count                  18.0                   18.0            18.0
# mean                   -3.0                   -3.0            -3.0
# std                     0.0                    0.0             0.0
# min                    -3.0                   -3.0            -3.0
# 25%                    -3.0                   -3.0            -3.0
# 50%                    -3.0                   -3.0            -3.0
# 75%                    -3.0                   -3.0            -3.0
# max                    -3.0                   -3.0            -3.0
#
#        COD_PREST_PAGAMENTO  CODIGO_SERVICO  QUANTIDADE  QTD_UNICA  VAL_CO  \
# count                 18.0    1.800000e+01   18.000000  18.000000    18.0
# mean                  -3.0    7.022725e+07    1.111111   1.111111     0.0
# std                    0.0    1.420702e+04    0.323381   0.323381     0.0
# min                   -3.0    7.019991e+07    1.000000   1.000000     0.0
# 25%                   -3.0    7.022315e+07    1.000000   1.000000     0.0
# 50%                   -3.0    7.022377e+07    1.000000   1.000000     0.0
# 75%                   -3.0    7.023701e+07    1.000000   1.000000     0.0
# max                   -3.0    7.025899e+07    2.000000   2.000000     0.0
#
#        VAL_FILME  VAL_BASE_CO  VAL_BASE_FILME  PARTICIPA_PREST  \
# count       18.0         18.0            18.0              0.0
# mean         0.0          0.0             0.0              NaN
# std          0.0          0.0             0.0              NaN
# min          0.0          0.0             0.0              NaN
# 25%          0.0          0.0             0.0              NaN
# 50%          0.0          0.0             0.0              NaN
# 75%          0.0          0.0             0.0              NaN
# max          0.0          0.0             0.0              NaN
#
#        TIPO_ATENDIMENTO
# count               0.0
# mean                NaN
# std                 NaN
# min                 NaN
# 25%                 NaN
# 50%                 NaN
# 75%                 NaN
# max                 NaN
